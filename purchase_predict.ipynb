# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# EDA

# %%
df = pd.read_csv('Social_Network.csv')

# %%
df.sample(5)
# Out:
#       User ID  Gender  Age  Salary  Purchased
# 164  15697574  Female   33   69000          0
# 339  15665760    Male   39  122000          1
# 224  15575002  Female   35   60000          0
# 182  15694288  Female   32  117000          1
# 263  15767681  Female   35   72000          0

# %%
df = df.iloc[:,2:]

# %%
df.sample(5)
# Out:
#      Age  Salary  Purchased
# 378   41   87000          1
# 306   51  134000          0
# 82    20   49000          0
# 149   20   74000          0
# 362   47   50000          1

# %% [markdown]
# Split Train & Test

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.drop('Purchased',axis=1),df['Purchased'],test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (320, 2)

# %%
x_test.shape
# Out:
# (80, 2)

# %% [markdown]
# Standardization

# %%
from sklearn.preprocessing import StandardScaler

scal = StandardScaler()
scal.fit(x_train)

x_train_scale = scal.transform(x_train)
x_test_scale = scal.transform(x_test)

scal.mean_
# Out:
# array([3.8218750e+01, 6.9928125e+04])

# %%
x_train
# Out:
#      Age  Salary
# 336   58  144000
# 64    59   83000
# 55    24   55000
# 106   26   35000
# 300   58   38000
# ..   ...     ...
# 323   48   30000
# 192   29   43000
# 117   36   52000
# 47    27   54000
# 172   26  118000
#
# [320 rows x 2 columns]

# %%
x_train_scale
# Out:
# array([[ 1.92295008e+00,  2.14601566e+00],
#        [ 2.02016082e+00,  3.78719297e-01],
#        [-1.38221530e+00, -4.32498705e-01],
#        [-1.18779381e+00, -1.01194013e+00],
#        [ 1.92295008e+00, -9.25023920e-01],
#        [ 3.67578135e-01,  2.91803083e-01],
#        [ 1.73156642e-01,  1.46942725e-01],
#        [ 2.02016082e+00,  1.74040666e+00],
#        [ 7.56421121e-01, -8.38107706e-01],
#        [ 2.70367388e-01, -2.87638347e-01],
#        [ 3.67578135e-01, -1.71750061e-01],
#        [-1.18475597e-01,  2.20395980e+00],
#        [-1.47942605e+00, -6.35303205e-01],
#        [-1.28500455e+00, -1.06988428e+00],
#        [-1.38221530e+00,  4.07691369e-01],
#        [-1.09058306e+00,  7.55356227e-01],
#        [-1.47942605e+00, -2.00722133e-01],
#        [ 9.50842613e-01, -1.06988428e+00],
#        [ 9.50842613e-01,  5.81523798e-01],
#        [ 3.67578135e-01,  9.87132798e-01],
#        [ 5.61999628e-01, -8.96051849e-01],
#        [-6.04529329e-01,  1.45068594e+00],
# ...

# %%
x_train_scale = pd.DataFrame(x_train_scale,columns=x_train.columns)
x_test_scale = pd.DataFrame(x_test_scale,columns=x_test.columns)

# %%
np.round(x_train.describe(),1)
# Out:
#          Age    Salary
# count  320.0     320.0
# mean    38.2   69928.1
# std     10.3   34570.1
# min     18.0   15000.0
# 25%     30.0   43000.0
# 50%     38.0   69500.0
# 75%     46.0   88000.0
# max     60.0  150000.0

# %%
np.round(x_train_scale.describe(),1)
# Out:
#          Age  Salary
# count  320.0   320.0
# mean     0.0     0.0
# std      1.0     1.0
# min     -2.0    -1.6
# 25%     -0.8    -0.8
# 50%     -0.0    -0.0
# 75%      0.8     0.5
# max      2.1     2.3

# %% [markdown]
# Effects of Standardization

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))

ax1.set_title('Before Scaling')
ax1.scatter(x_train['Age'],x_train['Salary'])

ax2.set_title('After Scaling')
ax2.scatter(x_train_scale['Age'],x_train_scale['Salary'],color='red')

plt.plot()
# Out:
# []

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))

ax1.set_title('Before Scaling')
sns.kdeplot(x_train['Age'],ax=ax1)
sns.kdeplot(x_train['Salary'],ax=ax1)

ax2.set_title('After Scaling')
sns.kdeplot(x_train_scale['Age'],ax=ax2)
sns.kdeplot(x_train_scale['Salary'],ax=ax2)

plt.plot()
# Out:
# c:\Users\Khushi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Khushi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Khushi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))

ax1.set_title('Before Scaling')
sns.kdeplot(x_train['Age'],ax=ax1)

ax2.set_title('After Scaling')
sns.kdeplot(x_train_scale['Age'],ax=ax2)

plt.plot()
# Out:
# c:\Users\Khushi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Khushi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# []

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))

ax1.set_title('Before Scaling')
sns.kdeplot(x_train['Salary'],ax=ax1)

ax2.set_title('After Scaling')
sns.kdeplot(x_train_scale['Salary'],ax=ax2)

plt.plot()
# Out:
# c:\Users\Khushi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Khushi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# []

# %%
# Both age & salary looks sames as scaled when they are ploted indivisually
# But they looks differents when ploted together due to range difference

# %% [markdown]
# LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr_scale = LogisticRegression()

# %%
lr.fit(x_train,y_train)
lr_scale.fit(x_train_scale,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)
y_pred_scale = lr_scale.predict(x_test_scale)

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_pred,y_test)
acc_scale = accuracy_score(y_pred_scale,y_test)

# %%
acc
# Out:
# 0.9125

# %%
acc_scale
# Out:
# 0.925

# %%
# Scaled model have better accuracy than un-scaled
